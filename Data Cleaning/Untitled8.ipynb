# %% [markdown]
# <a href="https://colab.research.google.com/github/Amitukra/Hotel-Booking-Analysis/blob/main/Data%20Cleaning/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 4

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/Hotel Bookings.csv')

# %%
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
pd.set_option('display.max_columns', None)  # Show all columns
df.sample(50)
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 70014     City Hotel            1        169               2017
# 15187   Resort Hotel            1        253               2015
# 6753    Resort Hotel            1        114               2016
# 27427   Resort Hotel            0         39               2016
# 281     Resort Hotel            0         44               2015
# 51694     City Hotel            1          5               2016
# 84334     City Hotel            0         78               2016
# 30530   Resort Hotel            0         31               2016
# 55747     City Hotel            1        133               2016
# 21401   Resort Hotel            0         23               2016
# 99895     City Hotel            0         58               2016
# 36265   Resort Hotel            0         94               2017
# 17806   Resort Hotel            0          1               2017
# 41553     City Hotel            1          1               2015
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df = df.drop(columns= ['company'])
df.dropna()
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# 5       Resort Hotel            0         14               2015
# 7       Resort Hotel            0          9               2015
# 8       Resort Hotel            1         85               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 3                    July                        27
# 4                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.shape
# Out:
# (119390, 31)

# %%
df[df['children'].isnull()]
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 40600  City Hotel            1          2               2015
# 40667  City Hotel            1          1               2015
# 40679  City Hotel            1          1               2015
# 41160  City Hotel            1          8               2015
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 40600             August                        32                          3
# 40667             August                        32                          5
# 40679             August                        32                          5
# 41160             August                        33                         13
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 40600                        1                     0       2       NaN
# 40667                        0                     2       2       NaN
# ...

# %%
df['children'] = df['children'].fillna(df['children'].mean())

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df[df['country'].isnull()].shape[0]
# Out:
# 488

# %%
df['country'].value_counts().head(10)
# Out:
# country
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# ITA     3766
# IRL     3375
# BEL     2342
# BRA     2224
# NLD     2104
# Name: count, dtype: int64

# %%
df.groupby('meal')['country'].value_counts().head(60)
# Out:
# meal  country
# BB    PRT        39556
#       GBR         9038
#       FRA         8009
#       ESP         5939
#       DEU         4702
#       IRL         2779
#       ITA         2456
#       BEL         1882
#       BRA         1743
#       NLD         1720
#       USA         1563
#       CHE         1324
#       AUT         1003
#       CN          1002
#       SWE          853
#       CHN          703
#       POL          700
#       ISR          555
#       NOR          494
#       RUS          463
#       FIN          389
#       ROU          369
#       DNK          368
#       AUS          312
#       AGO          274
#       MAR          206
#       TUR          200
#       LUX          199
#       HUN          180
#       ARG          160
#       JPN          153
#       CZE          152
#       IND          122
#       GRC          116
#       KOR          104
#       SRB           92
#       HRV           80
#       DZA           76
#       EST           68
# ...

# %%
df[df['country'].isnull()].groupby('meal').size().reset_index(name='null_country_count')
# Out:
#         meal  null_country_count
# 0         BB                 443
# 1         HB                  29
# 2         SC                  12
# 3  Undefined                   4

# %%
df['country'] = df.groupby('meal')['country'].transform(
    lambda x: x.fillna(x.mode()[0]) if not x.mode().empty else x
)

# %%
df['country'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['agent'].isnull().sum()
# Out:
# np.int64(16340)

# %%
df['agent'].fillna(0, inplace=True)
# Out:
# <ipython-input-385-c3e50b2f8523>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['agent'].fillna(0, inplace=True)

# %%
df['agent'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119390 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
print(df['children'].unique())
# Out:
# [ 0.         1.         2.        10.         3.         0.1038899]

# %%
df['children'].value_counts()
# Out:
# children
# 0.00000     110796
# 1.00000       4861
# 2.00000       3652
# 3.00000         76
# 0.10389          4
# 10.00000         1
# Name: count, dtype: int64

# %%
df = df[(df['children'] >= 0) & (df['children'] <= 5)]

# %%
df['children'] = df['children'].round().astype(int)
# Out:
# <ipython-input-391-1088a852883e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['children'] = df['children'].round().astype(int)

# %%
print(df['children'].unique())
# Out:
# [0 1 2 3]

# %%
df.sample(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 78566  City Hotel            0         12               2016
# 94298  City Hotel            0         13               2017
# 61889  City Hotel            1         12               2016
# 93125  City Hotel            0          5               2016
# 71177  City Hotel            1        107               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 78566               June                        25                         14
# 94298            January                         4                         25
# 61889           December                        53                         28
# 93125               July                        29                         14
# 71177               June                        26                         29
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# ...

# %%
print(f"Hotel Catogry : {df['hotel'].unique()}")
print(f"is_canceled Catogry : {df['is_canceled'].unique()}")
print(f"arrival_date_year Catogry : {df['arrival_date_year'].unique()}")
print(f"arrival_date_month Catogry : {df['arrival_date_month'].unique()}")
# Out:
# Hotel Catogry : ['Resort Hotel' 'City Hotel']
# is_canceled Catogry : [0 1]
# arrival_date_year Catogry : [2015 2016 2017]
# arrival_date_month Catogry : ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']

# %%
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"\nColumn: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}")
    print(f"Data type: {df[col].dtypes}")
# Out:
# Column: hotel
# Unique values (2): ['Resort Hotel' 'City Hotel']
# Data type: object
#
# Column: is_canceled
# Unique values (2): [0 1]
# Data type: int64
#
# Column: lead_time
# Unique values (479): [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
# ...

# %%
df['meal'].value_counts()
# Out:
# meal
# BB           92309
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: count, dtype: int64

# %%
df['meal'] = df['meal'].replace('Undefined','Unknown_Meal')
# Out:
# <ipython-input-397-1f966a0b6f61>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['meal'] = df['meal'].replace('Undefined','Unknown_Meal')

# %%
df['meal'].unique()
# Out:
# array(['BB', 'FB', 'HB', 'SC', 'Unknown_Meal'], dtype=object)

# %%
df['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97869
# Direct       14645
# Corporate     6677
# GDS            193
# Undefined        5
# Name: count, dtype: int64

# %%
df = df[df['distribution_channel'] != 'Undefined']

# %%
df['distribution_channel'].value_counts()
# Out:
# distribution_channel
# TA/TO        97869
# Direct       14645
# Corporate     6677
# GDS            193
# Name: count, dtype: int64

# %%
df['agent'] =df['agent'].round().astype(int)
# Out:
# <ipython-input-402-242f4013d513>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['agent'] =df['agent'].round().astype(int)

# %%
df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'],format='%Y-%m-%d')
# Out:
# <ipython-input-403-e365caac0328>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['reservation_status_date'] = pd.to_datetime(df['reservation_status_date'],format='%Y-%m-%d')

# %%
print(df['reservation_status_date'].dtype)
# Out:
# datetime64[ns]

# %%
df['reservation_status_date']
# Out:
# 0        2015-07-01
# 1        2015-07-01
# 2        2015-07-02
# 3        2015-07-02
# 4        2015-07-03
#             ...
# 119385   2017-09-06
# 119386   2017-09-07
# 119387   2017-09-07
# 119388   2017-09-07
# 119389   2017-09-07
# Name: reservation_status_date, Length: 119384, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 119384 entries, 0 to 119389
# Data columns (total 31 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119384 non-null  object
#  1   is_canceled                     119384 non-null  int64
#  2   lead_time                       119384 non-null  int64
#  3   arrival_date_year               119384 non-null  int64
#  4   arrival_date_month              119384 non-null  object
#  5   arrival_date_week_number        119384 non-null  int64
#  6   arrival_date_day_of_month       119384 non-null  int64
#  7   stays_in_weekend_nights         119384 non-null  int64
#  8   stays_in_week_nights            119384 non-null  int64
#  9   adults                          119384 non-null  int64
#  10  children                        119384 non-null  int64
#  11  babies                          119384 non-null  int64
# ...

# %%
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"\nColumn: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}")
    print(f"Data type: {df[col].dtypes}")
# Out:
# Column: hotel
# Unique values (2): ['Resort Hotel' 'City Hotel']
# Data type: object
#
# Column: is_canceled
# Unique values (2): [0 1]
# Data type: int64
#
# Column: lead_time
# Unique values (479): [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
# ...

# %%
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...
